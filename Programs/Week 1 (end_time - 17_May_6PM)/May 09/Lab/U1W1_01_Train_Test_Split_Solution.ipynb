# %% [markdown]
# # Train-Test Split Solution
#
# This notebook is a clean local solution for the train-test split experiment. It keeps the same dataset, the same split logic, and the same sklearn workflow as the original notebook, but removes the ID/password cells, the setup cell, and the feedback questions.
#
# Place `diabetes.csv` in the same folder as this notebook before running the cells.

# %% [markdown]
# ## Setup
#
# This notebook runs locally without any registration or password cells.
#
# To execute it, open the notebook in VS Code and run the cells in order. The dataset is fetched directly from the original hosted CSV URL, so no manual download is needed.

# %% [markdown]
# ## Learning Objective
#
# The goal of this experiment is to understand how a dataset is divided into training and test parts, and why that split is useful when evaluating a machine learning model.

# %% [markdown]
# ## Dataset Used
#
# The notebook uses `diabetes.csv` from the original experiment URL. The target column is `Outcome`, which is separated from the input features when we prepare the data for model training.
#
# The CSV is fetched directly from the original hosted dataset location, so there is no need to keep a local copy beside the notebook.

# %%
import pandas as pd

# %%
from urllib.request import urlopen
import pandas as pd

DATASET_URL = "https://cdn.iiith.talentsprint.com/aiml/Experiment_related_data/diabetes.csv"

dataframe = pd.read_csv(DATASET_URL)
dataframe.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataframe.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
type(dataframe)
# Out:
# pandas.DataFrame

# %% [markdown]
# ## Train-Test Split Evaluation
#
# The train-test split is a technique for assessing a machine learning algorithm's performance.
#
# The procedure involves dividing a dataset into two subsets. The first subset, known as the training dataset, is used to fit the model. The second subset is not used to train the model; instead, the model is fed the dataset's input element, and predictions are made and compared to expected values. The second dataset is known as the test dataset.
#
# * Train Dataset: Used to fit the machine learning model.
# * Test Dataset: Used to evaluate the fit machine learning model.
#
# The goal is to estimate the machine learning model's performance on new data that was not used to train the model.

# %%
shuffle_df = dataframe.sample(frac=1)
shuffle_df.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 68             1       95             66             13       38  19.6
# 263            3      142             80             15        0  32.4
# 88            15      136             70             32      110  37.1
# 313            3      113             50             10       85  29.5
# 428            0      135             94             46      145  40.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 68                      0.334   25        0
# 263                     0.200   63        0
# 88                      0.153   43        1
# 313                     0.626   25        0
# 428                     0.284   26        0

# %%
train_size = int(0.7 * len(dataframe))
print(train_size)

train_set = shuffle_df[:train_size]
test_set = shuffle_df[train_size:]
# Out:
# 537

# %%
print("train data :", len(train_set), ", test data :", len(test_set))
# Out:
# train data : 537 , test data : 231

# %%
train_set.groupby(['Outcome']).count()
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Outcome
# 0                351      351            351            351      351  351
# 1                186      186            186            186      186  186
#
#          DiabetesPedigreeFunction  Age
# Outcome
# 0                             351  351
# 1                             186  186

# %%
test_set.groupby(['Outcome']).count()
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Outcome
# 0                149      149            149            149      149  149
# 1                 82       82             82             82       82   82
#
#          DiabetesPedigreeFunction  Age
# Outcome
# 0                             149  149
# 1                              82   82

# %% [markdown]
# ## Train-Test Split With sklearn
#
# The second approach uses `train_test_split` from sklearn. Before splitting, the target column `Outcome` is separated from the input columns. This is the standard preparation step for supervised learning.

# %%
features = dataframe.drop('Outcome', axis=1)
target = dataframe['Outcome']

# %%
features
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
target
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((537, 8), (231, 8), (537,), (231,))

# %% [markdown]
# ## Summary
#
# Train-test split is used to measure how well a model may perform on unseen data. In this notebook, the same dataset is split in two ways: first manually with a shuffled 70/30 partition, and then with sklearn using `train_test_split` and `test_size=0.3`.
#
# For local execution, keep `diabetes.csv` in the same folder as this notebook.
